# %%
# Import dependencies
import pandas as pd

# %%
# Import csv
vine_df = pd.read_csv('vine_table.csv')

# %%
# print Vine DataFrame
vine_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 0      R1QX6706ZWJ1P5            5              0            0    N
# 1      R3QWMLJHIW6P37            5              0            0    N
# 2      R14Z1VR1N0Z9G6            5              1            1    N
# 3       R25ZRJL0GH0U0            2              0            0    N
# 4      R3837KYH7AZNIY            4              0            1    N
# ...               ...          ...            ...          ...  ...
# 85976  R1NUYN39WEVD9X            5             96           98    N
# 85977   RD17SQQ58L34O            5             46           48    N
# 85978  R30DX2RCMIKQ90            5             31           34    N
# 85979  R1O8C9XEYHQUIH            2             38           41    N
# 85980  R1WM4Y8G4DPHTL            5             19           21    N
#
#       verified_purchase
# 0                     Y
# 1                     Y
# 2                     Y
# 3                     Y
# ...

# %%
# Filter reviews on total votes greater than 20
vine_votes_df = vine_df[vine_df['total_votes'] >=20]

# %%
# Print DataFrame
vine_votes_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 884    R2PT2X8FMYFCV3            5             39           41    N
# 917     RGCUQSH80SYY7            1             36           47    N
# 939    R3E6EI073KP0AL            2             21           36    N
# 947    R3MYTXW7B4Z6YW            4            687          711    N
# 1211   R2WMF1IWN5ZYO4            5             18           24    N
# ...               ...          ...            ...          ...  ...
# 85976  R1NUYN39WEVD9X            5             96           98    N
# 85977   RD17SQQ58L34O            5             46           48    N
# 85978  R30DX2RCMIKQ90            5             31           34    N
# 85979  R1O8C9XEYHQUIH            2             38           41    N
# 85980  R1WM4Y8G4DPHTL            5             19           21    N
#
#       verified_purchase
# 884                   Y
# 917                   N
# 939                   Y
# 947                   Y
# ...

# %%
# Calculate percentage of helpful votes based on total votes
votes_calc = [vine_votes_df["helpful_votes"]/vine_votes_df["total_votes"] * 100]
votes_calc
# Out:
# [884      95.121951
#  917      76.595745
#  939      58.333333
#  947      96.624473
#  1211     75.000000
#             ...
#  85976    97.959184
#  85977    95.833333
#  85978    91.176471
#  85979    92.682927
#  85980    90.476190
#  Length: 3414, dtype: float64]

# %%
# Create additional column and add calculation
vine_votes_df.insert(6, "votes_calc", (vine_votes_df["helpful_votes"]/vine_votes_df["total_votes"] * 100), True)

# %%
vine_votes_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 884    R2PT2X8FMYFCV3            5             39           41    N
# 917     RGCUQSH80SYY7            1             36           47    N
# 939    R3E6EI073KP0AL            2             21           36    N
# 947    R3MYTXW7B4Z6YW            4            687          711    N
# 1211   R2WMF1IWN5ZYO4            5             18           24    N
# ...               ...          ...            ...          ...  ...
# 85976  R1NUYN39WEVD9X            5             96           98    N
# 85977   RD17SQQ58L34O            5             46           48    N
# 85978  R30DX2RCMIKQ90            5             31           34    N
# 85979  R1O8C9XEYHQUIH            2             38           41    N
# 85980  R1WM4Y8G4DPHTL            5             19           21    N
#
#       verified_purchase  votes_calc
# 884                   Y   95.121951
# 917                   N   76.595745
# 939                   Y   58.333333
# ...

# %%
# Create new DataFrame with filtered results based on percentage over 50%
filtered_vine_votes_df = vine_votes_df[vine_votes_df['votes_calc'] >=50]

# %%
filtered_vine_votes_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 884    R2PT2X8FMYFCV3            5             39           41    N
# 917     RGCUQSH80SYY7            1             36           47    N
# 939    R3E6EI073KP0AL            2             21           36    N
# 947    R3MYTXW7B4Z6YW            4            687          711    N
# 1211   R2WMF1IWN5ZYO4            5             18           24    N
# ...               ...          ...            ...          ...  ...
# 85976  R1NUYN39WEVD9X            5             96           98    N
# 85977   RD17SQQ58L34O            5             46           48    N
# 85978  R30DX2RCMIKQ90            5             31           34    N
# 85979  R1O8C9XEYHQUIH            2             38           41    N
# 85980  R1WM4Y8G4DPHTL            5             19           21    N
#
#       verified_purchase  votes_calc
# 884                   Y   95.121951
# 917                   N   76.595745
# 939                   Y   58.333333
# ...

# %%
# Create new DataFrame with filtered results over 50% and review is paid
vine_filtered_vine_votes_df = filtered_vine_votes_df[filtered_vine_votes_df['vine'] == 'Y']
vine_filtered_vine_votes_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 32351  R3R2RHQWEKX5NL            5             81           89    Y
# 32362  R1RZ4JZO8DAP7H            3            200          227    Y
# 32557   RQ94HI0WM8KIG            5            174          188    Y
#
#       verified_purchase  votes_calc
# 32351                 N   91.011236
# 32362                 N   88.105727
# 32557                 N   92.553191

# %%
# Create new DataFrame with filtered results over 50% and review is not paid
no_vine_filtered_vine_votes_df = filtered_vine_votes_df[filtered_vine_votes_df['vine'] == 'N']
no_vine_filtered_vine_votes_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 884    R2PT2X8FMYFCV3            5             39           41    N
# 917     RGCUQSH80SYY7            1             36           47    N
# 939    R3E6EI073KP0AL            2             21           36    N
# 947    R3MYTXW7B4Z6YW            4            687          711    N
# 1211   R2WMF1IWN5ZYO4            5             18           24    N
# ...               ...          ...            ...          ...  ...
# 85976  R1NUYN39WEVD9X            5             96           98    N
# 85977   RD17SQQ58L34O            5             46           48    N
# 85978  R30DX2RCMIKQ90            5             31           34    N
# 85979  R1O8C9XEYHQUIH            2             38           41    N
# 85980  R1WM4Y8G4DPHTL            5             19           21    N
#
#       verified_purchase  votes_calc
# 884                   Y   95.121951
# 917                   N   76.595745
# 939                   Y   58.333333
# ...

# %%
# Count for total reviews
index = vine_df.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 85981

# %%
# Create DataFrame for Vine reviews
vine_paid_df = vine_df[vine_df['vine']=='Y']
vine_paid_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 17581  R3EKQCOSRD87C5            5              0            0    Y
# 19183   RJCBWCZR4NNSZ            5              0            0    Y
# 19478  R1Q51GXKUZ5476            5              0            0    Y
# 19835  R2H37HMA4GYC6P            4              0            0    Y
# 19934  R1D1JCHS7J9TYJ            5              0            0    Y
# 19981    RALG7GNUS74W            5              0            0    Y
# 20031  R12TGFMSCAR7P1            5              1            1    Y
# 20141   RNKAFX7EC8ABA            5              0            0    Y
# 20168  R1M8X0LY2XVPXN            5              0            0    Y
# 20221   RE4JGQ8BYAPI1            5              0            0    Y
# 20236  R3RD517WVBE5PD            5              1            1    Y
# 20315  R2UZXZJDPEO1GC            5              0            0    Y
# 20358  R1AD9BIK2CNGPA            5              0            0    Y
# ...

# %%
# Count for total reviews
index = vine_paid_df.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 32

# %%
# Create DataFrame for Non-Vine reviews
vine_not_paid_df = vine_df[vine_df['vine']=='N']
vine_not_paid_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 0      R1QX6706ZWJ1P5            5              0            0    N
# 1      R3QWMLJHIW6P37            5              0            0    N
# 2      R14Z1VR1N0Z9G6            5              1            1    N
# 3       R25ZRJL0GH0U0            2              0            0    N
# 4      R3837KYH7AZNIY            4              0            1    N
# ...               ...          ...            ...          ...  ...
# 85976  R1NUYN39WEVD9X            5             96           98    N
# 85977   RD17SQQ58L34O            5             46           48    N
# 85978  R30DX2RCMIKQ90            5             31           34    N
# 85979  R1O8C9XEYHQUIH            2             38           41    N
# 85980  R1WM4Y8G4DPHTL            5             19           21    N
#
#       verified_purchase
# 0                     Y
# 1                     Y
# 2                     Y
# 3                     Y
# ...

# %%
# Count for total reviews
index = vine_not_paid_df.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 85949

# %%
# Create new DataFrame for 5 Star Reviews
vine_star_df = vine_df[vine_df['star_rating'] == 5]
vine_star_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 0      R1QX6706ZWJ1P5            5              0            0    N
# 1      R3QWMLJHIW6P37            5              0            0    N
# 2      R14Z1VR1N0Z9G6            5              1            1    N
# 5      R2MN0QYCY6EVIV            5              0            0    N
# 6      R3AN2UJ1D42ZS0            5              0            0    N
# ...               ...          ...            ...          ...  ...
# 85974  R1V5LPJM896HE5            5              1            5    N
# 85976  R1NUYN39WEVD9X            5             96           98    N
# 85977   RD17SQQ58L34O            5             46           48    N
# 85978  R30DX2RCMIKQ90            5             31           34    N
# 85980  R1WM4Y8G4DPHTL            5             19           21    N
#
#       verified_purchase
# 0                     Y
# 1                     Y
# 2                     Y
# 5                     Y
# ...

# %%
# Count for 5 star reviews
index = vine_star_df.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 48897

# %%
# Create new DataFrame with 5 star review and paid review
vine_star_paid_df = vine_star_df[vine_star_df['vine']=='Y']
vine_star_paid_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 17581  R3EKQCOSRD87C5            5              0            0    Y
# 19183   RJCBWCZR4NNSZ            5              0            0    Y
# 19478  R1Q51GXKUZ5476            5              0            0    Y
# 19934  R1D1JCHS7J9TYJ            5              0            0    Y
# 19981    RALG7GNUS74W            5              0            0    Y
# 20031  R12TGFMSCAR7P1            5              1            1    Y
# 20141   RNKAFX7EC8ABA            5              0            0    Y
# 20168  R1M8X0LY2XVPXN            5              0            0    Y
# 20221   RE4JGQ8BYAPI1            5              0            0    Y
# 20236  R3RD517WVBE5PD            5              1            1    Y
# 20315  R2UZXZJDPEO1GC            5              0            0    Y
# 20358  R1AD9BIK2CNGPA            5              0            0    Y
# 20468   REJDK05IQDG5S            5              0            0    Y
# ...

# %%
index = vine_star_paid_df.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 24

# %%
# Create new DataFrame with 5 star review and no paid review
vine_star_no_paid_df = vine_star_df[vine_star_df['vine']=='N']
vine_star_no_paid_df
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 0      R1QX6706ZWJ1P5            5              0            0    N
# 1      R3QWMLJHIW6P37            5              0            0    N
# 2      R14Z1VR1N0Z9G6            5              1            1    N
# 5      R2MN0QYCY6EVIV            5              0            0    N
# 6      R3AN2UJ1D42ZS0            5              0            0    N
# ...               ...          ...            ...          ...  ...
# 85974  R1V5LPJM896HE5            5              1            5    N
# 85976  R1NUYN39WEVD9X            5             96           98    N
# 85977   RD17SQQ58L34O            5             46           48    N
# 85978  R30DX2RCMIKQ90            5             31           34    N
# 85980  R1WM4Y8G4DPHTL            5             19           21    N
#
#       verified_purchase
# 0                     Y
# 1                     Y
# 2                     Y
# 5                     Y
# ...

# %%
index = vine_star_no_paid_df.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 48873
